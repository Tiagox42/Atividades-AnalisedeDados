# %%
# !pip install pymongo[srv]

# %%
import pymongo
from pymongo import MongoClient

# %%
client = pymongo.MongoClient("mongodb+srv://biscoito:biscoito@cluster0.c9oet.mongodb.net/analtel?retryWrites=true&w=majority")

# %%
client.list_database_names()
# Out:
# ['anatel', 'admin', 'local']

# %%
db = client.anatel

# %%
db.minas
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-01.c9oet.mongodb.net:27017', 'cluster0-shard-00-00.c9oet.mongodb.net:27017', 'cluster0-shard-00-02.c9oet.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-slucnj-shard-0', ssl=True), 'anatel'), 'minas')

# %%
db.minas.count_documents({})
# Out:
# 509706

# %%
list(db.minas.find().limit(5))
# Out:
# [{'_id': ObjectId('5fb2927724bad4108031664f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fb2927724bad41080316650'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 8},
#  {'_id': ObjectId('5fb2927724bad41080316651'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
# ...

# %%
db.minas.find({}).sort({ "QtdeSolic" : 1}).limit(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-c5eb7b817357> in <module>
# ----> 1 db.minas.find({}).sort({ "QtdeSolic" : 1}).limit(1)
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in sort(self, key_or_list, direction)
#     760         """
#     761         self.__check_okay_to_chain()
# --> 762         keys = helpers._index_list(key_or_list, direction)
#     763         self.__ordering = helpers._index_document(keys)
#     764         return self
#
# ~\anaconda3\lib\site-packages\pymongo\helpers.py in _index_list(key_or_list, direction)
#      72             return [(key_or_list, ASCENDING)]
#      73         elif not isinstance(key_or_list, (list, tuple)):
# ---> 74             raise TypeError("if no direction is specified, "
#      75                             "key_or_list must be an instance of list")
#      76         return key_or_list
#
# ...

# %%
list(db.minas.find({}).sort( { QtdeSolic : 1} ).limit(1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-000118657ff5> in <module>
# ----> 1 list(db.minas.find({}).sort( { QtdeSolic : 1} ).limit(1))
#
# NameError: name 'QtdeSolic' is not defined

# %%
db.minas.find({}).sort( { QtdeSolic : 1} );
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-9eb2dc1f691c> in <module>
# ----> 1 db.minas.find({}).sort( { QtdeSolic : 1} );
#
# NameError: name 'QtdeSolic' is not defined

# %%
não sei
# Out:
#   File "<ipython-input-101-3f9ce3d0c12a>", line 1
#     não sei
#         ^
# SyntaxError: invalid syntax

# %%
list(db.minas.find({"Tipo": "Reclamação" }))
# Out:
# [{'_id': ObjectId('5fb2927724bad41080316651'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb2927724bad41080316652'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb2927724bad41080316653'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
# ...

# %%
list(db.minas.distinct("Tipo"));
